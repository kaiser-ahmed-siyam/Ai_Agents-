# %%
import os 
from dotenv import load_dotenv, find_dotenv
from langchain_groq import ChatGroq
from langchain_community.tools.tavily_search import TavilySearchResults
# from langgraph.prebuilt import create_agents
from langchain_core.messages import HumanMessage
# from langchain.agents import create_react_agent

# %%
_ = load_dotenv(find_dotenv())  # Load environment variables from .env file

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

os.environ["GROQ_API_KEY"] = GROQ_API_KEY
os.environ["TAVILY_API_KEY"] = TAVILY_API_KEY

chatModel = ChatGroq(model="gpt-oss-120b")
search = TavilySearchResults(max_results=3)

# msg = [
#     ("system", "You are a helpful assistant that can answer questions about the world and provide information on a wide range of topics."
#     " You have access to the internet and can search for information to help answer questions. You are also able to provide summaries of"
#     " articles and other content you find online."),
#     ("human", "What is the capital of France?"),
# ]

# response = chatMOdel.invoke(msg)
# print(response)

# %%
tool = [search]
agent_executor = create_agent(chatModel, tool)

response = agent_executor.invoke({"messages":[HumanMessage(content="What is the top 10  movies in 2025?")]})
print(response)
# Out:
# C:\Users\kaise\AppData\Local\Temp\ipykernel_54056\1584060555.py:2: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(chatModel, tool)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[15], line 4
#       1 tool = [search]
#       2 agent_executor = create_react_agent(chatModel, tool)
# ----> 4 response = agent_executor.invoke({"messages": [HumanMessage(content="What is the top 10  movies in 2025?")]})
#       5 print(response)
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\pregel\main.py:3292, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3289             chunks.append(chunk)
#    3290 else:
#    3291     # v1: collect interrupts from updates stream
# -> 3292     for chunk in self.stream(
#    3293         input,
#    3294         config,
#    3295         context=context,
#    3296         stream_mode=(
#    3297             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3298         ),
#    3299         print_mode=print_mode,
#    3300         output_keys=output_keys,
#    3301         interrupt_before=interrupt_before,
#    3302         interrupt_after=interrupt_after,
#    3303         durability=durability,
#    3304         **kwargs,
#    3305     ):
#    3306         if stream_mode == "values":
#    3307             if len(chunk) == 2:
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\pregel\main.py:2725, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2723 for task in loop.match_cached_writes():
#    2724     loop.output_writes(task.id, task.writes, cached=True)
# -> 2725 for _ in runner.tick(
#    2726     [t for t in loop.tasks.values() if not t.writes],
#    2727     timeout=self.step_timeout,
#    2728     get_waiter=get_waiter,
#    2729     schedule_task=loop.accept_push,
#    2730 ):
#    2731     # emit output
#    2732     yield from _output(
#    2733         stream_mode,
#    2734         print_mode,
#    (...)   2740         _state_mapper,
#    2741     )
#    2742 loop.after_tick()
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\pregel\_retry.py:96, in run_with_retry(task, retry_policy, configurable)
#      94     task.writes.clear()
#      95     # run the task
# ---> 96     return task.proc.invoke(task.input, config)
#      97 except ParentCommand as exc:
#      98     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\_internal\_runnable.py:393, in RunnableCallable.invoke(self, input, config, **kwargs)
#     391     # run in context
#     392     with set_config_context(child_config, run) as context:
# --> 393         ret = context.run(self.func, *args, **kwargs)
#     394 except BaseException as e:
#     395     run_manager.on_chain_error(e)
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langgraph\prebuilt\chat_agent_executor.py:679, in create_react_agent.<locals>.call_model(state, runtime, config)
#     677     response = cast(AIMessage, dynamic_model.invoke(model_input, config))  # type: ignore[arg-type]
#     678 else:
# --> 679     response = cast(AIMessage, static_model.invoke(model_input, config))  # type: ignore[union-attr]
#     681 # add agent name to the AIMessage
#     682 response.name = name
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_core\runnables\base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_core\runnables\base.py:5695, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5688 @override
#    5689 def invoke(
#    5690     self,
#    (...)   5693     **kwargs: Any | None,
#    5694 ) -> Output:
# -> 5695     return self.bound.invoke(
#    5696         input,
#    5697         self._merge_configs(config),
#    5698         **{**self.kwargs, **kwargs},
#    5699     )
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1201, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1192 @override
#    1193 def generate_prompt(
#    1194     self,
#    (...)   1198     **kwargs: Any,
#    1199 ) -> LLMResult:
#    1200     prompt_messages = [p.to_messages() for p in prompts]
# -> 1201     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1010, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1007 for i, m in enumerate(input_messages):
#    1008     try:
#    1009         results.append(
# -> 1010             self._generate_with_cache(
#    1011                 m,
#    1012                 stop=stop,
#    1013                 run_manager=run_managers[i] if run_managers else None,
#    1014                 **kwargs,
#    1015             )
#    1016         )
#    1017     except BaseException as e:
#    1018         if run_managers:
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1313, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1311     result = generate_from_stream(iter(chunks))
#    1312 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1313     result = self._generate(
#    1314         messages, stop=stop, run_manager=run_manager, **kwargs
#    1315     )
#    1316 else:
#    1317     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\langchain_groq\chat_models.py:621, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     616 message_dicts, params = self._create_message_dicts(messages, stop)
#     617 params = {
#     618     **params,
#     619     **kwargs,
#     620 }
# --> 621 response = self.client.create(messages=message_dicts, **params)
#     622 return self._create_chat_result(response, params)
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\groq\resources\chat\completions.py:461, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     241 def create(
#     242     self,
#     243     *,
#    (...)    300     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     301 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     302     """
#     303     Creates a model response for the given chat conversation.
#     304
#    (...)    459       timeout: Override the client-level default timeout for this request, in seconds
#     460     """
# --> 461     return self._post(
#     462         "/openai/v1/chat/completions",
#     463         body=maybe_transform(
#     464             {
#     465                 "messages": messages,
#     466                 "model": model,
#     467                 "citation_options": citation_options,
#     468                 "compound_custom": compound_custom,
#     469                 "disable_tool_validation": disable_tool_validation,
#     470                 "documents": documents,
#     471                 "exclude_domains": exclude_domains,
#     472                 "frequency_penalty": frequency_penalty,
#     473                 "function_call": function_call,
#     474                 "functions": functions,
#     475                 "include_domains": include_domains,
#     476                 "include_reasoning": include_reasoning,
#     477                 "logit_bias": logit_bias,
#     478                 "logprobs": logprobs,
#     479                 "max_completion_tokens": max_completion_tokens,
#     480                 "max_tokens": max_tokens,
#     481                 "metadata": metadata,
#     482                 "n": n,
#     483                 "parallel_tool_calls": parallel_tool_calls,
#     484                 "presence_penalty": presence_penalty,
#     485                 "reasoning_effort": reasoning_effort,
#     486                 "reasoning_format": reasoning_format,
#     487                 "response_format": response_format,
#     488                 "search_settings": search_settings,
#     489                 "seed": seed,
#     490                 "service_tier": service_tier,
#     491                 "stop": stop,
#     492                 "store": store,
#     493                 "stream": stream,
#     494                 "temperature": temperature,
#     495                 "tool_choice": tool_choice,
#     496                 "tools": tools,
#     497                 "top_logprobs": top_logprobs,
#     498                 "top_p": top_p,
#     499                 "user": user,
#     500             },
#     501             completion_create_params.CompletionCreateParams,
#     502         ),
#     503         options=make_request_options(
#     504             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     505         ),
#     506         cast_to=ChatCompletion,
#     507         stream=stream or False,
#     508         stream_cls=Stream[ChatCompletionChunk],
#     509     )
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\groq\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\GanAi projects\Ai_Agents-\venv\Lib\site-packages\groq\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-oss-safeguard-20b` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'code': 'model_not_found'}}
# During task with name 'agent' and id 'c15eec20-8c54-6bbe-59b5-cf6aa3db27d8'
